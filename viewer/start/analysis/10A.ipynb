# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager
import matplotlib.animation as animation
from matplotlib.pyplot import figure
plt.rcParams.update({'font.size': 18})

# %%
data = np.loadtxt("2ndMid/10A.txt") 
arr = np.array(data)
arr[arr != 0]
average = np.mean(arr)
std = np.std(arr)
average, std
# Out:
# (9.677777777777777, 6.068274105318904)

# %%
plt.hist(arr)
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.title("Physics Midterm out of 20 (10A)")
plt.savefig('2ndMid/10A.png', bbox_inches='tight', pad_inches=1)
plt.show()
