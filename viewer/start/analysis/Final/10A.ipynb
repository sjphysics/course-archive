# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager
import matplotlib.animation as animation
from matplotlib.pyplot import figure
plt.rcParams.update({'font.size': 18})

# %%
data = np.loadtxt("txt/A.txt") 
arr = np.array(data)
arr[arr != 0]
average = np.mean(arr)
std = np.std(arr)
average, std
# Out:
# (74.23444444444445, 13.617386036576029)

# %%
plt.hist(arr)
plt.xlabel("Grade out of 100")
plt.ylabel("Number of Students")
plt.title("Final Grade for 10A")
plt.savefig('output/10A.png', bbox_inches='tight', pad_inches=1)
plt.show()
