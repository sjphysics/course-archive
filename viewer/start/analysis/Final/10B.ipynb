# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager
import matplotlib.animation as animation
from matplotlib.pyplot import figure
plt.rcParams.update({'font.size': 18})

# %%
data = np.loadtxt("txt/B.txt") 
arr = np.array(data)
arr[arr != 0]
average = np.mean(arr)
std = np.std(arr)
average, std
# Out:
# (74.68584905660379, 10.652076497709972)

# %%
plt.hist(arr)
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.title("Total Out Of 100 (10B)")
plt.savefig('output/10B.png', bbox_inches='tight', pad_inches=1)
plt.show()
