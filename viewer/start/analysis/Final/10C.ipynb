# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager
import matplotlib.animation as animation
from matplotlib.pyplot import figure
plt.rcParams.update({'font.size': 18})

# %%
data = np.loadtxt("txt/C.txt") 
arr = np.array(data)
arr[arr != 0]
average = np.mean(arr)
std = np.std(arr)
average, std
# Out:
# (75.6741379310345, 12.115184407278099)

# %%
plt.hist(arr)
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.title("Total Out Of 100 (10C)")
plt.savefig('output/10B.png', bbox_inches='tight', pad_inches=1)
plt.show()
