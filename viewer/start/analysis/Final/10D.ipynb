# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager
import matplotlib.animation as animation
from matplotlib.pyplot import figure
plt.rcParams.update({'font.size': 18})

# %%
data = np.loadtxt("txt/D.txt") 
arr = np.array(data)
arr[arr != 0]
average = np.mean(arr)
std = np.std(arr)
average, std
# Out:
# (73.81888888888889, 13.007541781976967)

# %%
plt.hist(arr)
plt.xlabel("Score")
plt.ylabel("Number of Students")
plt.title("Total Out Of 100 (10D)")
plt.savefig('output/10D.png', bbox_inches='tight', pad_inches=1)
plt.show()
